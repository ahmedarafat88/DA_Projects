# %% [markdown]
# # <p><center style="font-family:newtimeroman;font-size:180%;">Country Analysis </center></p>
#
# ### Table of contents :
#
# * [Import Libraries 🕵️‍♂️🕵️‍♂️](#1)
# * [Read Data 🕵️‍♂️🕵️‍♂️](#2)
# * [Explore Data 🕵️‍♂️🕵️‍♂️](#3)
# * [EDA 🕵️‍♂️🕵️‍♂️](#4)

# %% [markdown]
# **<a id="1"></a>
# # <p style="background-image: url(https://i.postimg.cc/K87ByXmr/stage5.jpg);font-family:camtasia;font-size:120%;color:white;text-align:center;border-radius:15px 50px; padding:7px">Import Libraries 🕵️‍♂️🕵️‍♂️</p>
# <a class="btn" href="#home">Tabel of Contents</a>

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %%matplotlib in

# %% [markdown]
# **<a id="2"></a>
# # <p style="background-image: url(https://i.postimg.cc/K87ByXmr/stage5.jpg);font-family:camtasia;font-size:120%;color:white;text-align:center;border-radius:15px 50px; padding:7px">Read Data 🕵️‍♂️🕵️‍♂️</p>
# <a class="btn" href="#home">Tabel of Contents</a>

# %%
# read data
data =pd.read_csv('data/countries.csv')
data.head()
# Out:
#    Rank   ID        Country      Continent  Population       IMF_GDP  \
# 0     1  840  United States  North America   339996.56  2.669515e+13
# 1     2  156          China           Asia  1425671.35  2.186548e+13
# 2     3  392          Japan           Asia   123294.51  5.291351e+12
# 3     4  276        Germany         Europe    83294.63  4.564778e+12
# 4     5  356          India           Asia  1428627.66  3.893670e+12
#
#          UN_GDP  GDP_per_capita
# 0  1.862448e+13        78515.94
# 1  1.121828e+13        15336.97
# 2  4.936212e+12        42916.35
# 3  3.477796e+12        54802.79
# 4  2.259642e+12         2725.46

# %%
data.shape
# Out:
# (212, 8)

# %% [markdown]
# **<a id="3"></a>
# # <p style="background-image: url(https://i.postimg.cc/K87ByXmr/stage5.jpg);font-family:camtasia;font-size:120%;color:white;text-align:center;border-radius:15px 50px; padding:7px">Explore Data 🕵️‍♂️🕵️‍♂️</p>
# <a class="btn" href="#home">Tabel of Contents</a>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212 entries, 0 to 211
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rank            212 non-null    int64
#  1   ID              212 non-null    int64
#  2   Country         212 non-null    object
#  3   Continent       212 non-null    object
#  4   Population      212 non-null    float64
#  5   IMF_GDP         212 non-null    float64
#  6   UN_GDP          212 non-null    float64
#  7   GDP_per_capita  212 non-null    float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 13.4+ KB

# %%
data.describe().T
# Out:
#                 count          mean           std     min           25%  \
# Rank            212.0  1.065000e+02  6.134330e+01    1.00  5.375000e+01
# ID              212.0  4.293208e+02  2.506499e+02    4.00  2.110000e+02
# Population      212.0  3.793169e+04  1.439021e+05    4.39  1.247810e+03
# IMF_GDP         212.0  5.213021e+11  2.448664e+12    0.00  2.880000e+09
# UN_GDP          212.0  3.541058e+11  1.576706e+12    0.00  4.638538e+09
# GDP_per_capita  212.0  1.966912e+04  2.803635e+04  278.43  2.484200e+03
#
#                          50%           75%           max
# Rank            1.065000e+02  1.592500e+02  2.120000e+02
# ID              4.290000e+02  6.422500e+02  8.940000e+02
# Population      6.967350e+03  2.756395e+04  1.428628e+06
# IMF_GDP         2.951600e+10  2.265350e+11  2.669515e+13
# UN_GDP          2.128999e+10  1.592921e+11  1.862448e+13
# GDP_per_capita  7.481425e+03  2.399743e+04  1.781966e+05

# %%
data.describe(include='O').T
# Out:
#           count unique            top freq
# Country     212    212  United States    1
# Continent   212      6         Africa   54

# %% [markdown]
# # Check Null values & Duplicated values

# %%
data.isna().sum()
# Out:
# Rank              0
# ID                0
# Country           0
# Continent         0
# Population        0
# IMF_GDP           0
# UN_GDP            0
# GDP_per_capita    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **<a id="4"></a>
# # <p style="background-image: url(https://i.postimg.cc/K87ByXmr/stage5.jpg);font-family:camtasia;font-size:120%;color:white;text-align:center;border-radius:15px 50px; padding:7px">EDA 🕵️‍♂️🕵️‍♂️</p>
# <a class="btn" href="#home">Tabel of Contents</a>

# %%
# The ten most populous countries 
top_10=data.groupby(['Country','Population'])['Population'].max().sort_values(ascending=False).index[0:10] 
top_10
# Out:
# MultiIndex([(        'India', 1428627.66),
#             (        'China', 1425671.35),
#             ('United States',  339996.56),
#             (    'Indonesia',  277534.12),
#             (     'Pakistan',  240485.66),
#             (      'Nigeria',  223804.63),
#             (       'Brazil',  216422.45),
#             (   'Bangladesh',  172954.32),
#             (       'Russia',  144444.36),
#             (       'Mexico',  128455.57)],
#            names=['Country', 'Population'])

# %%
country=[]
population=[]
for i in top_10:
    print(i[0],i[1])
    country.append(i[0])
    population.append(i[1])  
plt.figure(figsize=(20,10))    
plt.bar(x=country,height=population,color='red',width=0.5)
plt.xlabel('Country',fontsize=25)
plt.xticks(rotation=45,fontsize=20)
plt.ylabel('Population',fontsize=25)
plt.yticks(rotation=45,fontsize=20)
plt.title('The ten most populous countries',fontsize=30)
# Out:
# India 1428627.66
# China 1425671.35
# United States 339996.56
# Indonesia 277534.12
# Pakistan 240485.66
# Nigeria 223804.63
# Brazil 216422.45
# Bangladesh 172954.32
# Russia 144444.36
# Mexico 128455.57
# Text(0.5, 1.0, 'The ten most populous countries')

# %%
# The ten least populous countries
low_10=data.groupby(['Country','Population'])['Population'].max().sort_values(ascending=True).index[0:10] 
low_10
# Out:
# MultiIndex([(            'Montserrat',  4.39),
#             (                'Tuvalu',  11.4),
#             (                 'Nauru', 12.78),
#             (              'Anguilla',  15.9),
#             (          'Cook Islands', 17.04),
#             (                 'Palau', 18.06),
#             ('British Virgin Islands', 31.54),
#             (            'San Marino', 33.64),
#             (                'Monaco',  36.3),
#             (         'Liechtenstein', 39.58)],
#            names=['Country', 'Population'])

# %%
count=[]
popul=[]
for i in low_10:
    print(i[0],i[1])
    count.append(i[0])
    popul.append(i[1])  
plt.figure(figsize=(20,10))    
plt.bar(x=count,height=popul,color='red',width=0.5)
plt.xlabel('Country',fontsize=25)
plt.xticks(rotation=45,fontsize=20)
plt.ylabel('Population',fontsize=25)
plt.yticks(rotation=45,fontsize=20)
plt.title('The ten least populous countries',fontsize=30)
# Out:
# Montserrat 4.39
# Tuvalu 11.4
# Nauru 12.78
# Anguilla 15.9
# Cook Islands 17.04
# Palau 18.06
# British Virgin Islands 31.54
# San Marino 33.64
# Monaco 36.3
# Liechtenstein 39.58
# Text(0.5, 1.0, 'The ten least populous countries')

# %%
# The ten countries that consume the most from the IMF_GDP
IMF_top_10=data.groupby(['Country','IMF_GDP'])['IMF_GDP'].max().sort_values(ascending=False).index[0:10] 
IMF_top_10
# Out:
# MultiIndex([( 'United States', 26695150000000.0),
#             (         'China', 21865482000000.0),
#             (         'Japan',  5291351000000.0),
#             (       'Germany',  4564778000000.0),
#             (         'India',  3893670000000.0),
#             ('United Kingdom',  3686935000000.0),
#             (        'France',  3086226000000.0),
#             (        'Canada',  2362318000000.0),
#             (         'Italy',  2169384000000.0),
#             (        'Brazil',  1980483000000.0)],
#            names=['Country', 'IMF_GDP'])

# %%
x =[]
y = []
for i in IMF_top_10:
    x.append(i[0])
    y.append(i[1])
plt.Figure(figsize=(30,20))    
plt.bar(x = x , height=y , color='red',width=.5)    
plt.xlabel('Country',fontsize=15)
plt.xticks(rotation=45,fontsize=10)
plt.ylabel('IMF_GDP',fontsize=15)
plt.yticks(rotation=45,fontsize=10)
plt.title('The ten countries that consume the most from the IMF_GDP',fontsize=20)
# Out:
# Text(0.5, 1.0, 'The ten countries that consume the most from the IMF_GDP')

# %%
# The ten countries that consume the least from the IMF_GDP
IMF_low_10=data.groupby(['Country','IMF_GDP'])['IMF_GDP'].max().sort_values(ascending=True).index[0:10] 
IMF_low_10
# Out:
# MultiIndex([(           'Afghanistan', 0.0),
#             (      'French Polynesia', 0.0),
#             (              'Pakistan', 0.0),
#             (           'North Korea', 0.0),
#             (         'New Caledonia', 0.0),
#             (        'Cayman Islands', 0.0),
#             (            'Montserrat', 0.0),
#             ('British Virgin Islands', 0.0),
#             (                'Monaco', 0.0),
#             (         'Liechtenstein', 0.0)],
#            names=['Country', 'IMF_GDP'])

# %%
# The ten countries that consume the most from the UN_GDP
UN_top_10=data.groupby(['Country','UN_GDP'])['UN_GDP'].max().sort_values(ascending=False).index[0:10]
UN_top_10
# Out:
# MultiIndex([( 'United States', 18624475000000.0),
#             (         'China', 11218281029298.0),
#             (         'Japan',  4936211827875.0),
#             (       'Germany',  3477796274497.0),
#             ('United Kingdom',  2647898654635.0),
#             (        'France',  2465453975282.0),
#             (         'India',  2259642382872.0),
#             (         'Italy',  1858913163928.0),
#             (        'Brazil',  1795925681016.0),
#             (        'Canada',  1529760492201.0)],
#            names=['Country', 'UN_GDP'])

# %%
county =[]
un_gdp= []
for i in UN_top_10:
    county.append(i[0])
    un_gdp.append(i[1])
plt.Figure(figsize=(30,20))    
plt.bar(x = county , height=un_gdp , color='red',width=.5)    
plt.xlabel('Country',fontsize=15)
plt.xticks(rotation=45,fontsize=10)
plt.ylabel('UN_GDP',fontsize=15)
plt.yticks(rotation=45,fontsize=10)
plt.title('The ten countries that consume the most from the UN_GDP',fontsize=20)
# Out:
# Text(0.5, 1.0, 'The ten countries that consume the most from the UN_GDP')

# %%
# The ten countries that consume the least from the UN_GDP
UN_low_10=data.groupby(['Country','UN_GDP'])['UN_GDP'].max().sort_values(ascending=True).index[0:10]
UN_low_10
# Out:
# MultiIndex([(          'Taiwan',         0.0),
#             (        'Tanzania',         0.0),
#             (          'Tuvalu',  36697185.0),
#             (      'Montserrat',  62051375.0),
#             (           'Nauru', 103469824.0),
#             (        'Kiribati', 173655146.0),
#             ('Marshall Islands', 183000000.0),
#             (    'Cook Islands', 290194195.0),
#             (           'Palau', 310248000.0),
#             (      'Micronesia', 329895643.0)],
#            names=['Country', 'UN_GDP'])

# %%
couny =[]
UN_GD= []
for i in UN_low_10:
    couny.append(i[0])
    UN_GD.append(i[1])
plt.Figure(figsize=(30,20))    
plt.bar(x = couny , height=UN_GD , color='red',width=.5)    
plt.xlabel('Country',fontsize=15)
plt.xticks(rotation=45,fontsize=10)
plt.ylabel('UN_GDP',fontsize=15)
plt.yticks(rotation=45,fontsize=10)
plt.title('The ten countries that consume the least from the UN_GDP',fontsize=20)
# Out:
# Text(0.5, 1.0, 'The ten countries that consume the least from the UN_GDP')

# %%
# The top ten countries in terms of GDP per capita
GDP_top_10=data.groupby(['Country','GDP_per_capita'])['GDP_per_capita'].max().sort_values(ascending=False).index[0:10]
GDP_top_10
# Out:
# MultiIndex([(       'Monaco', 178196.57),
#             ('Liechtenstein', 156469.22),
#             (   'Luxembourg',  140161.1),
#             (      'Ireland', 111161.01),
#             (  'Switzerland', 100969.92),
#             (       'Norway', 100419.59),
#             (      'Bermuda',  95636.59),
#             (        'Qatar',  84065.95),
#             (      'Iceland',  78536.07),
#             ('United States',  78515.94)],
#            names=['Country', 'GDP_per_capita'])

# %%
cony =[]
GDP_per_capit= []
for i in GDP_top_10:
    cony.append(i[0])
    GDP_per_capit.append(i[1])
plt.Figure(figsize=(30,20))    
plt.bar(x = cony , height=GDP_per_capit , color='red',width=.5)    
plt.xlabel('Country',fontsize=15)
plt.xticks(rotation=45,fontsize=10)
plt.ylabel('GDP_per_capit',fontsize=15)
plt.yticks(rotation=45,fontsize=10)
plt.title('The top ten countries in terms of GDP per capita',fontsize=20)
# Out:
# Text(0.5, 1.0, 'The top ten countries in terms of GDP per capita')

# %%
# The ten lowest countries in terms of GDP per capita
GDP_low_10=data.groupby(['Country','GDP_per_capita'])['GDP_per_capita'].max().sort_values(ascending=True).index[0:10]
GDP_low_10
# Out:
# MultiIndex([(                 'Burundi', 278.43),
#             (             'Afghanistan', 479.05),
#             (            'Sierra Leone', 485.26),
#             (              'Madagascar', 500.86),
#             ('Central African Republic', 501.02),
#             (                 'Somalia', 506.25),
#             (                  'Malawi', 541.04),
#             (              'Mozambique', 575.83),
#             (                   'Niger', 636.07),
#             (             'North Korea', 641.75)],
#            names=['Country', 'GDP_per_capita'])

# %%
coy =[]
GDP_per_= []
for i in GDP_low_10:
    coy.append(i[0])
    GDP_per_.append(i[1])
plt.Figure(figsize=(30,20))    
plt.bar(x = coy , height=GDP_per_ , color='red',width=.5)    
plt.xlabel('Country',fontsize=15)
plt.xticks(rotation=45,fontsize=10)
plt.ylabel('GDP_per_capita',fontsize=15)
plt.yticks(rotation=45,fontsize=10)
plt.title('he ten lowest countries in terms of GDP per capita',fontsize=20)
# Out:
# Text(0.5, 1.0, 'he ten lowest countries in terms of GDP per capita')

# %%
sns.pairplot(data)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Check outliers

# %%
plt.figure(figsize=(10,5))
plt.xlabel('Population', fontsize=15)
plt.title("Check outliers of Population",fontsize=20)
sns.boxplot(data['Population'],color='r')
plt.ylabel('Value',fontsize=20)
plt.xlabel('Population',fontsize=20)
plt.grid(True)
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.show()

# %%
# remove outliers
q75,q25 = np.percentile(data['Population'],[75,25])
IQR = q75 - q25
min_out = q25 - 1.5 * IQR
max_out = q75 + 1.5 * IQR
print("q75= ",q75 ,"\n","q25= ", q25 ,"\n" ,"IQR= " ,IQR ,"\n","min_out= ", min_out ,"\n","max_out= ", max_out)
# Out:
# q75=  27563.9525
#  q25=  1247.81
#  IQR=  26316.142499999998
#  min_out=  -38226.40375
#  max_out=  67038.16625

# %%
# remove outlirers
data.Population[data['Population']> max_out]=max_out
data.Population[data['Population']< min_out]=min_out
sns.boxplot(data['Population'])
plt.title('Remove outliers of Population',fontsize=20)
plt.ylabel('Value',fontsize=20)
plt.xlabel('Population',fontsize=20)
plt.grid(True)
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_23/3917369166.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Population[data['Population']> max_out]=max_out
# /tmp/ipykernel_23/3917369166.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Population[data['Population']< min_out]=min_out

# %%
plt.figure(figsize=(10,5))
plt.xlabel('IMF_GDP', fontsize=15)
plt.title("Check outliers of IMF_GDP",fontsize=20)
sns.boxplot(data['IMF_GDP'],color='r')
plt.ylabel('Value',fontsize=20)
plt.xlabel('IMF_GDP',fontsize=20)
plt.grid(True)
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.show()

# %%
q75,q25 = np.percentile(data['IMF_GDP'],[75,25])
IQR = q75 - q25
min_out = q25 - 1.5 * IQR
max_out = q75 + 1.5 * IQR
print("q75= ",q75 ,"\n","q25= ", q25 ,"\n" ,"IQR= " ,IQR ,"\n","min_out= ", min_out ,"\n","max_out= ", max_out)
# Out:
# q75=  226535000000.0
#  q25=  2880000000.0
#  IQR=  223655000000.0
#  min_out=  -332602500000.0
#  max_out=  562017500000.0

# %%
# remove outlirers
data.IMF_GDP[data['IMF_GDP']> max_out]=max_out
data.IMF_GDP[data['IMF_GDP']< min_out]=min_out
sns.boxplot(data['IMF_GDP'])
plt.title('Remove outliers of IMF_GDP',fontsize=20)
plt.ylabel('Value',fontsize=20)
plt.xlabel('IMF_GDP',fontsize=20)
plt.grid(True)
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_23/891875010.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.IMF_GDP[data['IMF_GDP']> max_out]=max_out
# /tmp/ipykernel_23/891875010.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.IMF_GDP[data['IMF_GDP']< min_out]=min_out

# %%
plt.figure(figsize=(10,5))
plt.xlabel('UN_GDP', fontsize=15)
plt.title("Check outliers of UN_GDP",fontsize=20)
sns.boxplot(data['UN_GDP'],color='r')
# Out:
# <Axes: title={'center': 'Check outliers of UN_GDP'}, xlabel='UN_GDP'>

# %%
q75,q25 = np.percentile(data['UN_GDP'],[75,25])
IQR = q75 - q25
min_out = q25 - 1.5 * IQR
max_out = q75 + 1.5 * IQR
print("q75= ",q75 ,"\n","q25= ", q25 ,"\n" ,"IQR= " ,IQR ,"\n","min_out= ", min_out ,"\n","max_out= ", max_out)
# Out:
# q75=  159292109258.75
#  q25=  4638537812.0
#  IQR=  154653571446.75
#  min_out=  -227341819358.125
#  max_out=  391272466428.875

# %%
# remove outlirers
data.UN_GDP[data['UN_GDP']> max_out]=max_out
data.UN_GDP[data['UN_GDP']< min_out]=min_out
sns.boxplot(data['UN_GDP'])
plt.title('Remove outliers of UN_GDP',fontsize=20)
plt.ylabel('Value',fontsize=20)
plt.xlabel('UN_GDP',fontsize=20)
plt.grid(True)
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_23/1612464666.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.UN_GDP[data['UN_GDP']> max_out]=max_out
# /tmp/ipykernel_23/1612464666.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.UN_GDP[data['UN_GDP']< min_out]=min_out

# %%
plt.figure(figsize=(10,5))
plt.xlabel('GDP_per_capita', fontsize=15)
plt.title("Check outliers of GDP_per_capita",fontsize=20)
sns.boxplot(data['GDP_per_capita'],color='r')
# Out:
# <Axes: title={'center': 'Check outliers of GDP_per_capita'}, xlabel='GDP_per_capita'>

# %%
q75,q25 = np.percentile(data['GDP_per_capita'],[75,25])
IQR = q75 - q25
min_out = q25 - 1.5 * IQR
max_out = q75 + 1.5 * IQR
print("q75= ",q75 ,"\n","q25= ", q25 ,"\n" ,"IQR= " ,IQR ,"\n","min_out= ", min_out ,"\n","max_out= ", max_out)
# Out:
# q75=  23997.432500000003
#  q25=  2484.2
#  IQR=  21513.232500000002
#  min_out=  -29785.648750000004
#  max_out=  56267.28125000001

# %%
# remove outlirers
data.GDP_per_capita[data['GDP_per_capita']> max_out]=max_out
data.GDP_per_capita[data['GDP_per_capita']< min_out]=min_out
sns.boxplot(data['GDP_per_capita'])
plt.title('Remove outliers of GDP_per_capita',fontsize=20)
plt.ylabel('Value',fontsize=20)
plt.xlabel('GDP_per_capita',fontsize=20)
plt.grid(True)
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_23/4217948010.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.GDP_per_capita[data['GDP_per_capita']> max_out]=max_out
# /tmp/ipykernel_23/4217948010.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.GDP_per_capita[data['GDP_per_capita']< min_out]=min_out
